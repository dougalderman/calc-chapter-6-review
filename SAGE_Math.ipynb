# %%
#Problem 22

# %%
x = var('x')

# %%
y = var('y')

# %%
def f(x, y): return x^3 - 6*x*y + y^2 + 6*x + 3*y - 1/5

# %%
plot3d(f,(x,-8,8),(y,-15,15),color='blue',opacity=0.8)
# Out:
# Graphics3d Object

# %%
def fx(x, y): return derivative(f(x, y), x)

# %%
fx(x, y)
# Out:
# 3*x^2 - 6*y + 6

# %%
def fy(x, y): return derivative(f(x, y), y)

# %%
fy(x, y)
# Out:
# -6*x + 2*y + 3

# %%
fxx = derivative(f(x, y), x, 2)

# %%
fxx
# Out:
# 6*x

# %%
fyy = derivative(f(x, y), y, 2)

# %%
fyy
# Out:
# 2

# %%
fxy = derivative(fx(x, y), y)

# %%
fxy
# Out:
# -6

# %%
solve([fx(x, y)==0, fy(x, y)==0], x, y)
# Out:
# [[x == 5, y == (27/2)], [x == 1, y == (3/2)]]

# %%
def fxx(x, y): return 6*x

# %%
def D(x, y): return fxx(x, y)*fyy-(fxy)^2

# %%
D(5, 27/2)
# Out:
# 24

# %%
fxx(5, 27/2)
# Out:
# 30

# %%
D(1, 3/2)
# Out:
# -24

# %%
f(5, 27/2)
# Out:
# -549/20

# %%
#Problem 34

# %%
x = var('x')

# %%
y = var('y')

# %%
def f(x, y): return x^2 + 4*y^2

# %%
plot3d(f,(x,-5,5),(y,-5,5),color='blue',opacity=0.8)
# Out:
# Graphics3d Object

# %%
def fx(x, y): return derivative(f(x, y), x)

# %%
fx(x, y)
# Out:
# 2*x

# %%
def fy(x, y): return derivative(f(x, y), y)

# %%
fy(x, y)
# Out:
# 8*y

# %%
fxx = derivative(f(x, y), x, 2)

# %%
fxx
# Out:
# 2

# %%
fyy = derivative(f(x, y), y, 2)

# %%
fyy
# Out:
# 8

# %%
fxy = derivative(fx(x, y), y)

# %%
fxy
# Out:
# 0

# %%
solve([fx(x, y)==0, fy(x, y)==0], x, y)
# Out:
# [[x == 0, y == 0]]

# %%
def D(x, y): return fxx*fyy-(fxy)^2

# %%
D(x, y)
# Out:
# 16

# %%
f(0, 0)
# Out:
# 0
